# %%
import matplotlib.pyplot as plt
import numpy as np

# Core size and operations that we computed time one
cores = ['2','3', '4', '6', ]
operations = ['Load', 'Show', 'Preprocess', 'Analysis'] 
times = [
    [47.846, 0.662, 105.483, 23.28],  
    [31.146, 0.522, 78.079, 15.18],  
    [29.967, 0.578, 67.653, 14.09],  
    [22, 0.5, 42.27, 9.01] 
]

#
time_values = np.array(times)  
nr = np.arange(len(cores))  

# Colors and Bar Width
bar = 0.2
bar_colors = ['b', 'g', 'r', 'c']

plt.figure(figsize=(10, 6))

# Different bar for each operation
for i in range(len(operations)):
    plt.bar(nr + i * bar, time_values[:, i], bar, label=operations[i], color=bar_colors[i])

plt.xlabel("Cores")
plt.ylabel("Time (s)")
plt.title("Comparison of Operation Times for Different Number of Cores")
plt.xticks(nr + bar * 1.5, sizes)  
plt.legend()
plt.grid(axis='y', linestyle="--", alpha=0.7)

plt.show()
